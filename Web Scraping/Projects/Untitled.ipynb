# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://open.spotify.com/playlist/2WKT9LWsW6YD8OPc70mTXF'

# %%
source = requests.get(url)
source
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(source.text,'html.parser')
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# ...

# %%
allsong= soup.find('div',class_='JUa6JJNj7R_Y3i4P8YUX').find_all('div',class_='wbGUuBgShYJ7AJN775Uy')
for i in allsong:
    print(i.text)
# Out:
# 1Kahani Suno 2.0Kaifi Khalil
# 2Maan Meri JaanKing
# 3KesariyaPritam, Arijit Singh, Amitabh Bhattacharya
# 4Jhoome Jo PathaanVishal-Shekhar, Arijit Singh, Sukriti Kakar, Vishal Dadlani, Shekhar Ravjiani, Kumaar
# 5DakuChani Nattan, Inderpal Moga
# 6NostradamusCapo Corleone, Kuba Więcek
# 7Tere Pyaar MeinPritam, Arijit Singh, Amitabh Bhattacharya, Nikhita Gandhi
# 8BOYCOTTINGNikki Paige
# 9Besharam Rang (From "Pathaan")Vishal-Shekhar, Shilpa Rao, Caralisa Monteiro, Vishal Dadlani, Shekhar Ravjiani, Kumaar
# 10Malang SajnaSachet Tandon, Parampara Tandon, Kumaar
# 11Pyaar Hota Kayi Baar Hai (From "Tu Jhoothi Main Makkaar")Pritam, Arijit Singh, Amitabh Bhattacharya, Charan
# 12Tu Aake DekhleKing
# 135766Janina Bey
# 14Kali Kali Zulfon Ke (Lo-Fi)Madhur Sharma
# 15O Bedardeya (From "Tu Jhoothi Main Makkaar")Pritam, Arijit Singh, Amitabh Bhattacharya
# 16Don't Be CruelRich Fayden
# 17BallerShubh, Ikky
# 18No LoveShubh
# 19Dancing By MyselfEp!K
# 20Mi AmorSharn, 40k, The Paul
# ...

# %%
allsong= soup.find_all('div',class_='Type__TypeElement-sc-goli3j-0 dvSMET Btg2qHSuepFGBG6X0yEN')

# %%
time= soup.find("div", class_="Type__TypeElement-sc-goli3j-0 dvSMET Btg2qHSuepFGBG6X0yEN")

# %%
time
